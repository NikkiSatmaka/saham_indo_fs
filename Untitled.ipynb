# %%
import pandas as pd
import requests

# %%
abba_bs = pd.read_excel('lap_keuangan/ZIP/ABBA - BS.xlsx')
abba_cs = pd.read_excel('lap_keuangan/ZIP/ABBA - CS.xlsx')
abba_is = pd.read_excel('lap_keuangan/ZIP/ABBA - IS.xlsx')

# %%
pd.read_csv('https://analytics.rti.co.id/query_financial.jsp?type=2&code=BBRI&sector=81&period=A&0.05916599506589182', sep='|')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-50-48a1d9030b2e> in <module>
# ----> 1 pd.read_csv('https://analytics.rti.co.id/query_financial.jsp?type=2&code=BBRI&sector=81&period=A&0.05916599506589182', sep='|')
#
# ...

# %%
abba_bs.drop(index=list(range(0, 9)), inplace=True)

# %%
abba_bs.drop(columns=abba_bs.columns[:2], inplace=True)

# %%
abba_bs.drop(columns=abba_bs.columns[1:3], inplace=True)

# %%
abba_bs.columns[1:3]
# Out:
# Index(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Logout', 'Unnamed: 15', 'Profile\n',
#        'Unnamed: 17', 'Unnamed: 18'],
#       dtype='object')

# %%
abba_bs.columns = abba_bs.iloc[0]

# %%
abba_bs.columns
# Out:
# Index(['Period Ending:   (in Rp)\nCurrent Assets:',
#                                2020-06-30 00:00:00,
#                                                nan,
#                                2019-12-31 00:00:00,
#                                                nan,
#                                2018-12-31 00:00:00,
#                                                nan,
#                                                nan,
#                                2017-12-31 00:00:00,
#                                                nan,
#                                2016-12-31 00:00:00,
#                                2015-12-31 00:00:00,
#                                                nan,
#                                                nan,
#                                                nan],
#       dtype='object', name=9)

# %%
abba_bs
# Out:
# 9   Period Ending:   (in Rp)\nCurrent Assets:  2020-06-30 00:00:00  NaN  \
# 9   Period Ending:   (in Rp)\nCurrent Assets:  2020-06-30 00:00:00  NaN
# 10                  Cash and Cash Equivalents             33,365 M  NaN
# 11                            Net Receivables             60,366 M  NaN
# 12                                  Inventory              6,689 M  NaN
# 13                           Prepaid Expenses              7,380 M  NaN
# 14                       Other Current Assets             43,425 M  NaN
# 15                       Total Current Assets            151,224 M  NaN
# 16                        Deferred Tax Assets             23,277 M  NaN
# 17                           Longterm Assets:                  NaN  NaN
# 18                 Property Plant & Equipment             29,115 M  NaN
# 19                                   Goodwill                    -  NaN
# 20                          Intangible Assets             23,542 M  NaN
# ...

# %%
abda_cs = pd.read_excel('lap_keuangan/ZIP/ABDA - CS.xlsx')
abda_cs[abda_cs['Unnamed: 1'] == 'Cash Flow from Operating Activities']
# Out:
#   9/7/2020                                                                                                            PT RTI Infokom - Stock: Financial\nRTI Analytics   Analyze any stock, anywhere, anytime. Know when to buy, what to buy, and when to sell.  \
# 9                                                NaN
#
#                             Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 9  Cash Flow from Operating Activities        NaN  -89,502 M  -205,012 M
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Logout Unnamed: 10  Profile\n  \
# 9  -115,023 M   63,962 M        NaN  121,205 M     NaN   130,279 M        NaN
#
#    Unnamed: 12  Unnamed: 13
# 9          NaN          NaN

# %%
pd.read_excel('lap_keuangan/XLSX/AALI - CS.xlsx')
# Out:
#    9/7/2020                                                                                                            PT RTI Infokom - Stock: Financial\nRTI Analytics   Analyze any stock, anywhere, anytime. Know when to buy, what to buy, and when to sell.  \
# 0   Watchlist   Market Overview   Indices   Movers...
# 1          AALI
# 2                                             Summary
# 3   LVol  BVol  Bid       Offer   OVol  Freq  Volu...
# 4                                                 NaN
# 5   5       341    11350  11375  406    836    111...
# 6                            Cash Flow (M in Million)
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# ...
